# %%
import pandas as pd
pd.set_option("display.max_colwidth", 800)

# %%
# -----------------------------------
# Scenario: News summarization
# -----------------------------------
scenario = {
    "use_case": "News summarization",
    "industry": "Media / Information Services",
    "system_description": (
        "A generative AI system designed to produce concise summaries of news articles "
        "for internal briefings and limited external sharing."
    ),
    "key_risk": "Copyright, licensing, and data provenance across mixed data sources"
}

pd.DataFrame([scenario])
# Out:
#              use_case                      industry  \
# 0  News summarization  Media / Information Services
#
#                                                                                                                    system_description  \
# 0  A generative AI system designed to produce concise summaries of news articles for internal briefings and limited external sharing.
#
#                                                               key_risk
# 0  Copyright, licensing, and data provenance across mixed data sources

# %%
# -----------------------------------
# Load the dataset manifest from CSV
# -----------------------------------
manifest = pd.read_csv("training_data_manifest.csv")

manifest
# Out:
#   source_id                          source_name     source_type  \
# 0   SRC-001                 Licensed News Feed A   licensed_feed
# 1   SRC-002    Company Knowledge Base (internal)   internal_docs
# 2   SRC-003        Public Web Articles (scraped)      web_scrape
# 3   SRC-004       Archived News Dataset (legacy)  legacy_dataset
# 4   SRC-005  Creative Commons Blog Posts (CC BY)    open_license
#
#   owner_or_provider        license_type             usage_rights  \
# 0          Vendor A  commercial_license  summarize_internal_only
# 1            Client               owned             internal_use
# 2           Various             unknown                  unknown
# 3           Unknown             missing                  missing
# 4           Various               CC BY   reuse_with_attribution
#
#   redistribution_allowed                    allowed_actions  \
# 0                  False  summarize; no_quotes; no_fulltext
# 1                   True  summarize; quote_with_attribution
# 2                unknown                            unknown
# 3                unknown                            unknown
# 4                   True  summarize; quote_with_attribution
#
#   provenance_confidence contains_pii  \
# 0                  high     unlikely
# 1                  high     possible
# 2                   low     possible
# 3                   low     unlikely
# 4                medium     possible
#
#                                                                                  notes
# 0  Contract allows internal summaries, prohibits redistribution and verbatim excerpts.
# 1                Internal policies may include names or emails; requires PII scanning.
# 2                    High risk source with unclear rights and potential takedown risk.
# 3                     Legacy dataset without documentation; origin and rights unclear.
# 4                        Attribution required; verify each item is legitimately CC BY.

# %%
# -----------------------------------
# What reviewers look at first
# -----------------------------------
# These are the columns reviewers tend to scan immediately
review_view = manifest[
    [
        "source_id",
        "source_name",
        "source_type",
        "license_type",
        "usage_rights",
        "redistribution_allowed",
        "provenance_confidence",
        "contains_pii"
    ]
]

review_view
# Out:
#   source_id                          source_name     source_type  \
# 0   SRC-001                 Licensed News Feed A   licensed_feed
# 1   SRC-002    Company Knowledge Base (internal)   internal_docs
# 2   SRC-003        Public Web Articles (scraped)      web_scrape
# 3   SRC-004       Archived News Dataset (legacy)  legacy_dataset
# 4   SRC-005  Creative Commons Blog Posts (CC BY)    open_license
#
#          license_type             usage_rights redistribution_allowed  \
# 0  commercial_license  summarize_internal_only                  False
# 1               owned             internal_use                   True
# 2             unknown                  unknown                unknown
# 3             missing                  missing                unknown
# 4               CC BY   reuse_with_attribution                   True
#
#   provenance_confidence contains_pii
# 0                  high     unlikely
# 1                  high     possible
# 2                   low     possible
# 3                   low     unlikely
# 4                medium     possible

# %%
# -----------------------------------
# Flag common licensing and lineage risks
# -----------------------------------
def flag_risks(df):
    df = df.copy()

    def is_unknown(value):
        return str(value).lower() in ["unknown", "missing", "", "nan"]

    df["risk_license_unclear"] = (
        df["license_type"].apply(is_unknown)
        | df["usage_rights"].apply(is_unknown)
    )

    df["risk_low_provenance"] = df["provenance_confidence"].str.lower().eq("low")

    # This system supports limited external sharing
    intended_external_use = True
    df["risk_redistribution_conflict"] = df["redistribution_allowed"].apply(
        lambda x: x is False and intended_external_use
    )

    df["risk_possible_pii"] = df["contains_pii"].str.lower().eq("possible")

    def overall_risk(row):
        hits = sum(
            [
                row["risk_license_unclear"],
                row["risk_low_provenance"],
                row["risk_redistribution_conflict"],
                row["risk_possible_pii"],
            ]
        )
        if hits >= 3:
            return "high"
        elif hits == 2:
            return "medium"
        elif hits == 1:
            return "low"
        return "none"

    df["overall_risk"] = df.apply(overall_risk, axis=1)
    return df

manifest_with_risk = flag_risks(manifest)

manifest_with_risk[
    [
        "source_id",
        "source_name",
        "overall_risk",
        "risk_license_unclear",
        "risk_low_provenance",
        "risk_redistribution_conflict",
        "risk_possible_pii",
    ]
].sort_values(by="overall_risk", ascending=False)
# Out:
#   source_id                          source_name overall_risk  \
# 0   SRC-001                 Licensed News Feed A         none
# 3   SRC-004       Archived News Dataset (legacy)       medium
# 1   SRC-002    Company Knowledge Base (internal)          low
# 4   SRC-005  Creative Commons Blog Posts (CC BY)          low
# 2   SRC-003        Public Web Articles (scraped)         high
#
#    risk_license_unclear  risk_low_provenance  risk_redistribution_conflict  \
# 0                 False                False                         False
# 3                  True                 True                         False
# 1                 False                False                         False
# 4                 False                False                         False
# 2                  True                 True                         False
#
#    risk_possible_pii
# 0              False
# 3              False
# 1               True
# 4               True
# 2               True

# %%
# -----------------------------------
# Reviewer-style summary table
# -----------------------------------
review_summary = pd.DataFrame(
    [
        {
            "Reviewer focus": "Unclear or missing licenses",
            "Why it matters": "Data with unknown rights creates legal exposure and blocks safe reuse.",
            "Example in this system": "Scraped web articles and legacy datasets",
        },
        {
            "Reviewer focus": "Low provenance confidence",
            "Why it matters": "If origin can't be traced, risk cannot be defended.",
            "Example in this system": "Legacy archive with no documentation",
        },
        {
            "Reviewer focus": "Redistribution conflicts",
            "Why it matters": "Internal-only data influencing externally shared outputs is a red flag.",
            "Example in this system": "Licensed news feed restricted to internal summaries",
        },
        {
            "Reviewer focus": "Potential PII exposure",
            "Why it matters": "Personal data can leak into training pairs or summaries.",
            "Example in this system": "Internal knowledge base and CC blog content",
        },
    ]
)

review_summary
# Out:
#                 Reviewer focus  \
# 0  Unclear or missing licenses
# 1    Low provenance confidence
# 2     Redistribution conflicts
# 3       Potential PII exposure
#
#                                                             Why it matters  \
# 0   Data with unknown rights creates legal exposure and blocks safe reuse.
# 1                      If origin can't be traced, risk cannot be defended.
# 2  Internal-only data influencing externally shared outputs is a red flag.
# 3                 Personal data can leak into training pairs or summaries.
#
#                                 Example in this system
# 0             Scraped web articles and legacy datasets
# 1                 Legacy archive with no documentation
# 2  Licensed news feed restricted to internal summaries
# 3          Internal knowledge base and CC blog content
